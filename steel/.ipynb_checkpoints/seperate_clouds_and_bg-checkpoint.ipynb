# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import pandas as pd
import skimage.io as io

# %%
df = pd.read_csv('../train.csv')

# %%
df.sample(6)
# Out:
#               Image_Label                                      EncodedPixels
# 11429  822ef2b.jpg_Flower                                                NaN
# 20188    e891f41.jpg_Fish                                                NaN
# 19379   e00ba80.jpg_Sugar  141500 150 142900 150 144300 150 145700 150 14...
# 17570  cac37e0.jpg_Gravel  135990 1210 137390 1210 138790 1210 140190 121...
# 18462  d5a6430.jpg_Gravel  746 471 2146 471 3546 471 4946 471 6346 471 77...
# 676      0879076.jpg_Fish  1753540 544 1754940 544 1756340 544 1757740 54...

# %%
img = io.imread('../train_rsz/0879076.png')

# %%
im2 = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
io.imshow(im2)

# %%
th3 = cv.adaptiveThreshold(im2,1,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,31,-5)
plt.imshow(th3,cmap='gray')

# %%
msk = io.imread('../fish/lbl_fish_rsz/0879076.png')
io.imshow(msk)

# %%
msk_b = msk.astype(np.bool)

# %%
th3.shape,msk_b.shape
# Out:
# ((350, 525), (350, 525))

# %%
_ = th3*msk_b

# %%
io.imshow(_)

# %%
# make fish labels

# %%
th3 = cv.adaptiveThreshold(im2,1,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,21,-5)
plt.imshow(th3,cmap='gray')

# %%
fig = plt.figure(figsize=(12,6))
dft = cv.dft(np.float32(im2),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(im2,cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
rows, cols = im2.shape
crow,ccol = rows//2 , cols//2

# create a mask first, center square is 1, remaining all zeros
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-10:crow+10, ccol-10:ccol+10] = 1

# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv.idft(f_ishift)
img_back = cv.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.subplot(121),plt.imshow(im2, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img_back.shape
# Out:
# (350, 525)

# %%
img_back1 = (img_back-img_back.mean())/img_back.std()

# %%
im21 = (im2-im2.mean())/im2.std()

# %%
plt.imshow(im21,cmap='gray')

# %%
im3 = cv.blur(im2,ksize=(5,5),cv.GaussianBlur)
# Out:
#   File "<ipython-input-75-b3c901765762>", line 1
#     im3 = cv.blur(im2,ksize=(5,5),cv.GaussianBlur)
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
io.imshow(im2+(im2-im3))

# %%
hist = cv.calcHist([im2],[0],None,[256],[0,256])

# %%
plt.plot(list(range(0,256)),hist)

# %%
msk = (im2>50)

# %%
io.imshow(msk)

# %%
# create a CLAHE object (Arguments are optional).
clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(im2)

# %%
io.imshow(cl1)
